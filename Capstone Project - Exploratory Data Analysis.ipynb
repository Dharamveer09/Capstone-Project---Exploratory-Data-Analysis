# %% [markdown]
# # **AirBnb Booking Analysis**    -

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Project Owner Name** - Dharamveer Yadav

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project revolves around analyzing data from around 49,000 Airbnb bookings to uncover insights that can help both guests and hosts improve their experiences. The ultimate goal is to provide valuable information to management and stakeholders, enabling them to make decisions that will help grow the business.
#
# ### **Key Areas of Focus:**
#
#
# 1.   **Understanding Guest Preferences**.
#
#
#
# *   **Room Type Preference**: By analyzing the data, we can determine which types of rooms guests prefer the most. This information will be useful for hosts to tailor their offerings to meet guest expectations better.
#
# *   **Price Range**: We'll look into the price ranges that are most appealing to guests. This will help in setting competitive prices that attract more bookings.
#
# *   **Neighborhood Popularity**: The data will also reveal which neighborhoods are the most sought-after by guests. Hosts in these areas can leverage this information to highlight the unique features of their locations.
#
#
#
#
# 2. **Improving Host Offerings.**
#
#
#
# *   **Ranking Hosts:**
#
# We’ll develop a system to rank hosts based on how well they meet guest preferences. This will encourage hosts to improve their services and match guest expectations, leading to higher satisfaction.
# *  **Feedback on Improvement:**
#
# By analyzing reviews, we can provide hosts with specific feedback on what they can improve to get more bookings and better ratings.
#
# 3.   **Enhanced Customer Experience:**
#
#
#
# *   **Filtering System:**
#
# The project aims to create a filter system for guests, allowing them to find listings that match their budget and preferences easily. This will make the booking process smoother and more personalized.
# *   **Targeted Solutions:**
#
# By understanding specific guest needs, we can help hosts cater to these needs better, ensuring a more fulfilling experience for both parties.
#
#
#
# # **Tools and Techniques:**
#
#
#
# **Data Wrangling with Pandas:**
#
# We’ll use the Pandas library to clean and organize the data. This will involve creating new data frames, organizing information, and preparing the data for further analysis. Proper data wrangling ensures that the data is clear and meaningful, making it easier to extract insights.
#
#
# **Numerical Computation with NumPy:**
#
# NumPy will be employed for numerical computations and to create arrays that will store and process data efficiently. This is crucial for tasks like ranking hosts and analyzing price trends.
#
#
# **Data Visualization with Matplotlib and Seaborn:**
#
# Visualizing the data is essential for understanding and presenting the findings clearly. We’ll use Matplotlib and Seaborn to create charts and graphs that will make it easier for stakeholders to grasp the insights and make informed decisions.
#
#
# # **Learning Outcomes:**
#
# This project is not just about analyzing data but also about understanding the dynamics of the Airbnb business model. You will learn how to think critically about real-world problems, identify patterns, and create data-driven solutions. The project will enhance your skills in using key data science libraries like Pandas, NumPy, Matplotlib, and Seaborn, and improve your ability to communicate complex data insights in a simple and impactful way. By the end of the project, you will have a deeper understanding of how to apply data science concepts to real-life situations, ultimately helping you grow as a data analyst.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **This project aims to analyze Airbnb booking data to identify trends in guest preferences and host performance, providing actionable insights to improve customer satisfaction and drive business growth.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to leverage data analysis to enhance the Airbnb platform's value proposition for both guests and hosts. By uncovering patterns in booking preferences, pricing, neighborhood popularity, and host performance, the project aims to guide strategic decisions that will improve customer experience, optimize host offerings, and ultimately drive increased bookings and business growth.Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math
import seaborn as sns
import openpyxl
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ### Dataset Loading

# %%
# Creating a dataframe of the given dataset

# pd.read_csv returns a pandas DataFrame object.

airbnb_df = pd.read_csv("Airbnb NYC 2019 (2).csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

airbnb_df.head(2)   # It gives the first five rows of the data with all columns
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

airbnb_df.shape  # 'shape' method gives (rows, column) count.
# Out:
# (48895, 16)

# %% [markdown]
# Shape of the dataset is (48895, 16) which means, there are 48895 rows and 16 columns

# %%
# let's see the total columns in the dataset

airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# From above info we can say,
# there are 3 columns which have 'float64' data type,
# 7 have int64 data type and
# 6 have 'object' data type.
#
# We can also conclude that there are some missing  values in 'name', 'host_name', 'last_review' & 'review_per_month' columns.

# %%
# 'Describing' Dataset

airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

duplicate_values = airbnb_df[airbnb_df.duplicated()]

# Display the number of duplicate rows
print(f"Number of duplicate rows: {duplicate_values.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
# If you want to check for duplicates based on specific columns only, you can specify them in the duplicated() method:

# duplicate_values = airbnb_df[airbnb_df.duplicated(subset=['column1', 'column2'])]

# %% [markdown]
# **As we can see from the output that there are no any duplicate rows in this dataset.**

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_values = airbnb_df.isnull().sum()
missing_values
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values

plt.figure(figsize=(12, 6))
sns.heatmap(airbnb_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Based on the initial exploration of the Airbnb dataset, here are some key observations:**
#
#
#
# 1.   **Dataset Structure:**
#
#
# *   The dataset contains around 49,000 observations, each representing a unique Airbnb listing in New York City.
# *   It includes multiple columns with various types of data, such as numerical (e.g., price), categorical (e.g., neighborhood group, room type or shared room), and textual data (e.g., name, host name).
#
#
# 2.   **Key Columns:**
#
#
#
# *   **Listing Information:** Columns like id, name, host_id, and host_name provide identifiers and basic information about the listings and their hosts.
# *  **Location Data:** neighbourhood_group and neighbourhood specify the broader and specific areas where the listings are located.
#
# *   **Room and Price Data:** room_type specifies the type of accommodation (e.g., entire home, private room), while price indicates the cost per night.
# *  **Availability and Popularity:** Columns like number_of_reviews, reviews_per_month, and availability_365 give insights into the listing's popularity and availability throughout the year.
#
#
# 3.   **Missing Values:**
#
#
# *   Some columns contain missing values, particularly those related to reviews (reviews_per_month) and host names. The extent of missing data varies, and this needs to be handled carefully, either by imputing values or by excluding those rows from analysis.
#
#
# 4.   **Duplicate Rows:**
# *   The dataset contains no duplicate values.
#
#
#
# 5.   **Price Distribution:**
#
#
# *   Prices vary significantly across the listings, with some outliers. Limiting the visualization to a specific range (e.g., below $500 per night) can help in understanding the general price trends.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe

airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# As we can see that we are having various outputs that can be studied so as to attain certain measures and draw conclusions on the basis of the data. For example: we have a wide range of prices available, however the average price range prefered by the customers are around 150, which gives us an idea on the budget of the guests and their preference.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

def unique_value(df):
  for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for '{column}': {unique_values}")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

start = 0
end = 10000
breakpoints = np.linspace(start, end, num=101)
breakpoints = breakpoints.astype(int)
def price_range(amt):
    bp = breakpoints
    for i in range(len(breakpoints)-1):
        if bp[i] <= amt <= bp[i+1]:
            return f"{bp[i]} - {bp[i+1]}"


airbnb_df['price_range'] = airbnb_df['price'].apply(lambda amt: price_range(amt))
airbnb_df['price_range']
# Out:
# 0        100 - 200
# 1        200 - 300
# 2        100 - 200
# 3          0 - 100
# 4          0 - 100
#            ...
# 48890      0 - 100
# 48891      0 - 100
# 48892    100 - 200
# 48893      0 - 100
# 48894      0 - 100
# Name: price_range, Length: 48895, dtype: object

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 : Room Type Distribution

# %%
# Get the room types and their counts
room_types = airbnb_df['room_type'].value_counts()

# Create a bar chart
plt.figure(figsize=(8, 5))
plt.bar(room_types.index, room_types.values)  # Plot bars for each room type and count

# Set labels and title
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Distribution of Room Types')

# Rotate x-axis labels for better readability if there are many room types
plt.xticks(rotation=0)  # Optional: rotate x-axis labels for better readability

plt.tight_layout()  # Adjust spacing between elements
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since 'room type' column contains categorical data, the bar chart is the best to explain the outcome.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Below are insights:**
#
# *   The 'Entire home/apt room_type' & 'private room' are booked in hightest number. They make nearly 95% of total room booked.
#
#
# *   The 'Shared room' is booked least.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help in creating a positive business impact. It give idea about the room preferences. It states people prefer 'Entire home/apt' or 'private rooms' much more over 'Shared room'. So host should list 'shared room' as less as possible.

# %% [markdown]
# #### Chart  - 2: Price Districution

# %%
# Plot the distribution of prices

plt.figure(figsize=(8, 5))
sns.histplot(airbnb_df['price'], bins=50, kde=True)
plt.title('Distribution of Prices')
plt.xlim(0, 500)  # Limit x-axis for better visualization
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The price distribution chart is chosen because price is a critical factor for both guests and hosts in the Airbnb platform. Understanding how prices are distributed across the listings can reveal important patterns and insights that can directly impact business strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Graph shows tha peope are booking more room which cost them less than 200
# *   Small fraction of people books in the range of  200 to  400.
# *   And very small fraction of people booked more than $400 room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hosts can use the insights to adjust their pricing to be more competitive or to target specific customer segments. For example, if a host’s listing is priced significantly higher than similar properties, they might lower the price to attract more bookings.
#
# By understanding the most common price ranges, Airbnb can tailor its marketing efforts to attract customers within those segments, thereby increasing booking rates.
#
# Guests are likely to be more satisfied if they find listings that match their budget and expectations. By aligning pricing with market demand, Airbnb can improve the overall customer experience.

# %% [markdown]
# #### Chart - 3 : Price vs. Room Type

# %%
# Chart - 3 visualization code

plt.figure(figsize=(10, 6))
sns.boxplot(data=airbnb_df, x='room_type', y='price')
plt.title('Price vs. Room Type')
plt.ylim(0, 500)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This boxplot compares prices across different room types to see if certain room types are priced higher than others. It’s essential to understand how room types influence pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Typically, entire homes/apartments might have higher prices than private or shared rooms.
#
# *   This graph also shows the price variability within each room type, including outliers.
# *   Hosts can see if they are pricing their listings too high or too low compared to similar room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, accurate pricing leads to better market positioning and can increase both bookings and revenue.

# %% [markdown]
# #### Chart - 4 : Price vs. Neighborhood Group

# %%
# Chart - 4 visualization code

plt.figure(figsize=(12, 6))
sns.boxplot(data=airbnb_df, x='neighbourhood_group', y='price')
plt.title('Price vs. Neighborhood Group')
plt.ylim(0, 500)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This boxplot visualizes how prices vary across different neighborhood groups. Location is a significant factor in real estate pricing, and this graph helps capture that relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Some neighborhoods may command higher prices due to their desirability, proximity to attractions, or overall cost of living. For ex - Manhattan.
#
# *   The variation in prices within neighborhoods can be seen, indicating areas where premium or budget options are available.
# *   Outliers can indicate either luxury properties or potential pricing errors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **For Hosts:** Helps hosts price their listings according to the neighborhood they are in. They can adjust their prices to align with neighborhood norms or to stand out.
#
# *   **For Airbnb:** This information can be used to highlight neighborhood-specific trends, helping guests find the best locations within their budget. Airbnb can also target marketing campaigns to highlight neighborhoods with specific pricing trends.

# %% [markdown]
# **Potential Negative Impact:** If Airbnb heavily promotes high-priced neighborhoods, it might alienate budget-conscious travelers, reducing bookings in those areas.
#
# **Justification:** A focus on premium pricing without balancing offerings for various budget segments could lead to a loss of customers who seek affordable options, negatively impacting growth in less affluent markets.

# %% [markdown]
# #### Chart - 5 : Availability vs. Neighborhood Group

# %%
# Chart - 5 visualization code

plt.figure(figsize=(12, 6))
sns.boxplot(data=airbnb_df, x='neighbourhood_group', y='availability_365')
plt.title('Availability vs. Neighborhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This boxplot looks at the availability of listings across different neighborhood groups, showing how many days per year listings are available for booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Neighborhoods with higher availability might indicate lower demand or a higher concentration of listings.
#
# *   Conversely, neighborhoods with lower availability might suggest high demand, possibly leading to higher prices.
# *   The variation in availability across neighborhoods helps in understanding where supply might exceed or lag behind demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **For Hosts:** If a listing has high availability in a neighborhood where most listings are fully booked, the host might need to adjust pricing or marketing strategies to attract more bookings.
#
# *   **For Airbnb:** Helps the platform identify areas with potential oversupply or undersupply. Airbnb can then target efforts to either attract more listings in high-demand areas or boost demand in areas with high availability.

# %% [markdown]
# **Potential Negative Impact:**
#
#
# *   **Over-Saturation:** If hosts in neighborhoods with high availability (indicating low occupancy) attempt to increase their occupancy by further promoting their listings, it could lead to an oversupply of available listings in those neighborhoods. This might increase competition among hosts, causing them to lower prices or offer additional incentives to attract guests, which could reduce profitability.
#
# *   **Neglect of Under-Supplied Areas:** On the flip side, neighborhoods with lower availability (indicating higher occupancy) might get overlooked for further development or investment. If the focus is solely on neighborhoods with high availability, the potential to tap into high-demand areas might be missed, leading to missed revenue opportunities.
#
#
# **Justification:**
#
#
#
# *  **Over-Saturation:** Too much focus on increasing availability in certain areas can lead to lower occupancy rates and decreased profitability.
# *   **Neglect of High-Demand Areas:** Failing to invest in high-demand neighborhoods could result in lost revenue and reduced market share.

# %% [markdown]
# #### Chart - 6 : Number of Reviews Distribution

# %%
# Chart - 6 visualization code

plt.figure(figsize=(8, 5))
sns.histplot(airbnb_df['number_of_reviews'], bins=50, kde=True)
plt.title('Number of Reviews Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The number of reviews is an indicator of how popular or frequently booked a listing is. This histogram shows how review counts are distributed across the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Listings with a high number of reviews are likely more popular or have been available for a longer time.
#
# *  A large number of listings with few or no reviews might suggest newer listings or those that are less frequently booked.
# *   This graph helps identify whether there's a healthy level of guest engagement with the listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **For Hosts:** Understanding how their review count compares to others can help hosts gauge their listing’s popularity. They might work on improving their listings or service to encourage more reviews.
# *   **For Airbnb:** Insights from this graph can be used to encourage hosts to seek more reviews, perhaps through incentives. More reviews generally lead to better trust and higher bookings.

# %% [markdown]
# #### Chart - 7 : Reviews per Month vs. Price

# %%
# Chart - 7 visualization code

plt.figure(figsize=(10, 6))
sns.scatterplot(data=airbnb_df, x='reviews_per_month', y='price')
plt.title('Reviews per Month vs. Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot examines the relationship between the price of a listing and the frequency of reviews per month. It helps in understanding how pricing might influence guest engagement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Listings with more reviews per month might indicate high guest turnover, possibly suggesting that they are priced attractively.
# *   Conversely, listings with high prices but few reviews may indicate overpricing or a niche market.
# *   The pattern can reveal whether lower or higher-priced listings are more frequently reviewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **For Hosts:** Helps them balance pricing with guest engagement. If high-priced listings are receiving fewer reviews, hosts might consider adjusting the price or offering additional value to attract more bookings.
# *   **For Airbnb:** Insights from this graph can help the platform in guiding hosts to price their listings effectively to increase guest engagement, leading to better overall satisfaction and more repeat customers.

# %% [markdown]
# **Potential Negative Impact:**
#
#
#
# *  **Focusing Too Much on High-Review, Low-Priced Listings:** If the focus shifts towards promoting or maintaining low-priced listings that receive frequent reviews, it could drive down overall pricing. This might attract budget-conscious travelers, but could also lower the average revenue per booking and diminish the perceived value of higher-priced listings.
#
# *   **Neglecting High-Priced, Low-Review Listings:** High-priced listings that receive fewer reviews might be perceived as less desirable. Ignoring these listings could lead to underutilization, as guests might opt for more frequently reviewed but lower-priced options. This could result in decreased revenue for hosts with premium properties.
#
# Yes, these insights can help tailor pricing and marketing strategies to maximize engagement and revenue. However, an overemphasis on low-priced, high-review listings could potentially lead to negative growth if it drives down overall pricing and profitability or neglects the premium market segment. Balancing the focus between different price segments is key to ensuring positive business outcomes.

# %% [markdown]
# #### Chart - 8 : Correlation Heatmap

# %%
# Chart - 8 visualization code

# Select only numeric columns
numeric_df = airbnb_df.select_dtypes(include=['float64', 'int64'])

# Now, create the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap visualizes the relationships between numerical variables in the dataset. It’s essential for identifying how variables influence each other, which can be crucial for predictive modeling and understanding underlying patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Strong correlations between variables can indicate that one variable is a good predictor of another. For example, price might be correlated with the number of reviews or availability.
# *   Weak or no correlations suggest that variables are independent, which can also be useful information.
# *   This heatmap helps identify potential multicollinearity issues if two or more variables are highly correlated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   **For Hosts:** Understanding which factors correlate with price or reviews can help hosts optimize their listings (e.g., improving features that are strongly associated with higher prices).
# *   **For Airbnb:** This information is valuable for creating recommendation systems, pricing algorithms, and other data-driven strategies. It helps Airbnb refine its platform to better meet the needs of both hosts and guests.

# %% [markdown]
# #### Chart - 9 - Pair Plot

# %%
numeric_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']

# Create the pair plot
sns.pairplot(airbnb_df[numeric_columns])
plt.suptitle('Pair Plot of Selected Numeric Features', y=1.02)  # Adjust title positioning
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   The pair plot shows scatter plots of all possible pairs of the selected numeric columns. This helps in understanding how each pair of variables relates to one another.
# *   By visualizing these relationships, you can easily spot trends, correlations, and potential patterns. This is particularly useful for identifying which variables are

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Price vs. Number of Reviews:** You can check if there is a relationship between the price of a listing and the number of reviews. For example, higher prices might correlate with more reviews or vice versa.
# *  **Availability vs. Minimum Nights:** You can explore if there's a relationship between how available a listing is and the minimum number of nights required for booking.
# *  **Price Distribution:** The histogram for price will show if most listings are priced low or high, and if there are any outliers.
#
#
#
# *  **Identify Outliers:** Outliers or unusual data points will stand out in scatter plots. For example, a listing with an extremely high price but very few reviews could be an outlier.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.   **Optimize Pricing Strategy**
#
#
#
# *   **Analyze Pricing Trends:** Use insights from the pair plot and other analyses to understand how pricing correlates with reviews, availability, and other factors. Adjust pricing strategies based on demand, seasonality, and competition.
# *   **Dynamic Pricing:** Implement dynamic pricing strategies that adjust rates based on factors such as booking lead time, occupancy rates, and local events.
#
#
#
# 2.   **Enhance Listing Quality**
#
#
#
# *   **Focus on High Review Counts:** Listings with higher reviews often perform better. Encourage hosts to improve their offerings to increase review counts.
# *   Review Analysis: Analyze review data to identify common feedback themes. Use this information to guide hosts on areas for improvement.
#
#
#
# 3.   **Improve Availability Management**
#
#
#
# *   **Availability vs. Minimum Nights:** Optimize availability settings to balance between maximizing bookings and maintaining profitability. For instance, if listings with lower minimum nights tend to attract more bookings, consider adjusting minimum stay requirements.
#
#
# 4.   **Enhance Customer Experience**
#
#
#
# *   **Personalized Recommendations:** Use insights on pricing and reviews to offer personalized recommendations to guests. Highlight well-reviewed listings that match their preferences.
# *   **Guest Feedback:** Continuously collect and analyze guest feedback to make data-driven improvements to the user experience.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# **Coming up to the solution of our business objective, we have throughly studied the whole data set and drawn some conclusions based on that, here are all the pointers we can take into consideration.**
#
# *  0-300 is the most prefered price range, which gives us a clear idea on what basis we will have to create our pricing.
#
# *   Entire home/apt being the most prefered room type makes it obvious that customers are very much concerned about their privacy and safety, we can create more relevant policies regarding their safety and privacy, ulimately resulting in gaining their trust and creating goodwill.
#
# *   We know that the most prefered area is the Financial District which is in the Manhattan Neighbourhood Group, hence we can create recommendations as per the pricing and area preferrences.
#
# *   The most reviews are also given to the same area itself we can take into consideration those points which proved to be the most satisfying for our customers so that we can make such changes in the other neighbourhoods, if possible, whcih will result in getting us more business in the other areas as well.
#
# *   I personally feel that this dataset should have one more column as per the occupation of the customer, it will create different groups of our customers based upon their occupation, which will help us to determine the preference of people coming from different sectors and we can identify which group of customers prefers which kind of accomodations.
# *   This dataset also gave us a good idea on the budget of the majority of our consumer market, and now just that we were able to see the ratio of prefered pricing.
#
# *   We were clearly able to see where most of our business lies and which consumer group creates the most of the business for us, we can make improvements in those and not just that we can also focus on the other sectors as well so that we can expand our business even more.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
